# %%
# 포폴에도 Seaborn 쓴거 있어야 해요
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
study = pd.read_csv("../../Data/study/2007~2022유치원_대학_사설학원.csv",index_col=0)
study
# Out:
#        시점       지역  사설학원수  대학교_숫자  중학생인원수변화  초등학생인원수변화  고등학생인원수변화  유치원원아수변화  \
# 0    2007      경기도  15591      61    489548     951908     411732    135245
# 1    2007    서울특별시  11549      50    375937     665227     355193     82461
# 2    2007     경상남도   5844      19    138629     264776     137276     44188
# 3    2007    부산광역시   4779      22    144991     242193     106501     37921
# 4    2007    대구광역시   2929      11    113962     199471     105396     27908
# ..    ...      ...    ...     ...       ...        ...        ...       ...
# 267  2022     충청북도   2381      17     42601      83827      39153     14993
# 268  2022    대전광역시   2294      15     40303      76960      39112     20405
# 269  2022      강원도   2264      17     37922      71530      36821     13168
# 270  2022  제주특별자치도   1167       4     20126      41628      18093      5945
# 271  2022  세종특별자치시    920       3     14809      32230      11484      6422
#
#       대학생숫자
# 0    485552
# 1    541288
# 2    139584
# ...

# %%
il = pd.read_csv("../../Data/companies/정제_업종_전부(2013~2020).csv")
il.head(2)
# Out:
#    협회 및 단체, 수리 및 기타 개인서비스업_활동  협회 및 단체, 수리 및 기타 개인서비스업_신생  \
# 0                       47929                        5870
# 1                       17554                        1892
#
#    협회 및 단체, 수리 및 기타 개인서비스업_소멸  예술, 스포츠 및 여가관련 서비스업_활동  예술, 스포츠 및 여가관련 서비스업_신생  \
# 0                        6229                   24426                    4488
# 1                        2093                    6967                    1146
#
#    예술, 스포츠 및 여가관련 서비스업_소멸  보건업 및 사회복지 서비스업_활동  보건업 및 사회복지 서비스업_신생  \
# 0                    4716               18641                1666
# 1                    1292                5023                 394
#
#    보건업 및 사회복지 서비스업_소멸  교육서비스업_활동  ...  전기, 가스, 증기 및 공기조절 공급업_신생  \
# 0                1389      28184  ...                        45
# 1                 280       8354  ...                        14
#
#    전기, 가스, 증기 및 공기조절 공급업_소멸  제조업_활동  제조업_신생  제조업_소멸  광업_활동  광업_신생  광업_소멸  \
# 0                         9   74080    7362    6401     53      6      4
# ...

# %%
il.년도
# Out:
# 0      2013
# 1      2013
# 2      2013
# 3      2013
# 4      2013
#        ...
# 131    2020
# 132    2020
# 133    2020
# 134    2020
# 135    2020
# Name: 년도, Length: 136, dtype: int64

# %%
study = study[(study["시점"]>2012) & (study["시점"]<2021)]
study
# Out:
#        시점       지역  사설학원수  대학교_숫자  중학생인원수변화  초등학생인원수변화  고등학생인원수변화  유치원원아수변화  \
# 102  2013      경기도  18134      62    458220     739619     460580    182231
# 103  2013    서울특별시  13405      48    304251     469392     334123     92400
# 104  2013     경상남도   5662      20    124566     190166     122060     50370
# 105  2013    부산광역시   4638      22    110454     160821     105310     44217
# 106  2013    대구광역시   3639      11     94394     136309     103666     34550
# ..    ...      ...    ...     ...       ...        ...        ...       ...
# 233  2020     충청북도   2232      17     41458      85135      42488     16049
# 234  2020    대전광역시   2198      15     40694      79807      41549     22132
# 235  2020      강원도   2179      17     37836      73478      39806     14679
# 236  2020  제주특별자치도   1051       4     19468      40575      18679      6395
# 237  2020  세종특별자치시    689       3     12395      29487      10246      6763
#
#       대학생숫자
# 102  499221
# 103  570583
# 104  129823
# ...

# %%
len(il.index)
# Out:
# 136

# %%
len(study.index)
# Out:
# 136

# %%
il.년도
il.시도
il["시점"] = il.년도
il["지역"] = il.시도

# %%
il = il.drop(columns=["시도","년도"])
il.head(2)
# Out:
#    협회 및 단체, 수리 및 기타 개인서비스업_활동  협회 및 단체, 수리 및 기타 개인서비스업_신생  \
# 0                       47929                        5870
# 1                       17554                        1892
#
#    협회 및 단체, 수리 및 기타 개인서비스업_소멸  예술, 스포츠 및 여가관련 서비스업_활동  예술, 스포츠 및 여가관련 서비스업_신생  \
# 0                        6229                   24426                    4488
# 1                        2093                    6967                    1146
#
#    예술, 스포츠 및 여가관련 서비스업_소멸  보건업 및 사회복지 서비스업_활동  보건업 및 사회복지 서비스업_신생  \
# 0                    4716               18641                1666
# 1                    1292                5023                 394
#
#    보건업 및 사회복지 서비스업_소멸  교육서비스업_활동  ...  전기, 가스, 증기 및 공기조절 공급업_신생  \
# 0                1389      28184  ...                        45
# 1                 280       8354  ...                        14
#
#    전기, 가스, 증기 및 공기조절 공급업_소멸  제조업_활동  제조업_신생  제조업_소멸  광업_활동  광업_신생  광업_소멸  \
# 0                         9   74080    7362    6401     53      6      4
# ...

# %%
study
# Out:
#        시점       지역  사설학원수  대학교_숫자  중학생인원수변화  초등학생인원수변화  고등학생인원수변화  유치원원아수변화  \
# 102  2013      경기도  18134      62    458220     739619     460580    182231
# 103  2013    서울특별시  13405      48    304251     469392     334123     92400
# 104  2013     경상남도   5662      20    124566     190166     122060     50370
# 105  2013    부산광역시   4638      22    110454     160821     105310     44217
# 106  2013    대구광역시   3639      11     94394     136309     103666     34550
# ..    ...      ...    ...     ...       ...        ...        ...       ...
# 233  2020     충청북도   2232      17     41458      85135      42488     16049
# 234  2020    대전광역시   2198      15     40694      79807      41549     22132
# 235  2020      강원도   2179      17     37836      73478      39806     14679
# 236  2020  제주특별자치도   1051       4     19468      40575      18679      6395
# 237  2020  세종특별자치시    689       3     12395      29487      10246      6763
#
#       대학생숫자
# 102  499221
# 103  570583
# 104  129823
# ...

# %%
test = pd.merge(il,study,on=["시점","지역"])
test
# Out:
#      협회 및 단체, 수리 및 기타 개인서비스업_활동  협회 및 단체, 수리 및 기타 개인서비스업_신생  \
# 0                         47929                        5870
# 1                         17554                        1892
# 2                         11126                        1400
# 3                         12099                        1931
# 4                          7586                        1086
# ..                          ...                         ...
# 131                       11770                        1675
# 132                       11167                        1733
# 133                       17024                        2354
# 134                       21223                        3176
# 135                        4745                         703
#
#      협회 및 단체, 수리 및 기타 개인서비스업_소멸  예술, 스포츠 및 여가관련 서비스업_활동  \
# 0                          6229                   24426
# 1                          2093                    6967
# 2                          1301                    5129
# ...

# %%
len(test.columns)
# Out:
# 60

# %%
test = test.iloc[:,:54]
test
# Out:
#      협회 및 단체, 수리 및 기타 개인서비스업_활동  협회 및 단체, 수리 및 기타 개인서비스업_신생  \
# 0                         47929                        5870
# 1                         17554                        1892
# 2                         11126                        1400
# 3                         12099                        1931
# 4                          7586                        1086
# ..                          ...                         ...
# 131                       11770                        1675
# 132                       11167                        1733
# 133                       17024                        2354
# 134                       21223                        3176
# 135                        4745                         703
#
#      협회 및 단체, 수리 및 기타 개인서비스업_소멸  예술, 스포츠 및 여가관련 서비스업_활동  \
# 0                          6229                   24426
# 1                          2093                    6967
# 2                          1301                    5129
# ...

# %%
test
# Out:
#      협회 및 단체, 수리 및 기타 개인서비스업_활동  협회 및 단체, 수리 및 기타 개인서비스업_신생  \
# 0                         47929                        5870
# 1                         17554                        1892
# 2                         11126                        1400
# 3                         12099                        1931
# 4                          7586                        1086
# ..                          ...                         ...
# 131                       11770                        1675
# 132                       11167                        1733
# 133                       17024                        2354
# 134                       21223                        3176
# 135                        4745                         703
#
#      협회 및 단체, 수리 및 기타 개인서비스업_소멸  예술, 스포츠 및 여가관련 서비스업_활동  \
# 0                          6229                   24426
# 1                          2093                    6967
# 2                          1301                    5129
# ...

# %%
pop = pd.read_csv("../../Data/sangwonKim/순이동인구_시도_시_군_구__20230207.csv",encoding="euc-kr")
pop
# Out:
#     행정구역(시군구)별(1)     2013    2014     2015     2016    2017     2018    2019  \
# 0   행정구역(시군구)별(1)        계       계        계        계       계        계       계
# 1              전국        0       0        0        0       0        0       0
# 2           서울특별시  -100550  -87831  -137256  -140257  -98486  -110230  -49588
# 3           부산광역시   -17710  -15092   -13560   -21392  -28398   -26759  -23354
# 4           대구광역시   -11351  -15526   -12940    -9260  -11936   -14242  -23673
# 5           인천광역시    22035    9324     9538     5777   -1670      -67   -2337
# 6           광주광역시    -2592   -2977    -9272    -7898   -8118    -6216   -3875
# 7           대전광역시      311   -8838   -20616   -10631  -16175   -14753  -16342
# 8           울산광역시     2307    2786      -80    -7622  -11917   -12654  -10172
# 9         세종특별자치시     8696   33456    53044    29816   34690    31433   23724
# 10            경기도    74131   57396    94768   133617  116162   170094  134666
# ...

# %%
pop = pop.iloc[2:,:]
pop
# Out:
#    행정구역(시군구)별(1)     2013    2014     2015     2016    2017     2018    2019  \
# 2          서울특별시  -100550  -87831  -137256  -140257  -98486  -110230  -49588
# 3          부산광역시   -17710  -15092   -13560   -21392  -28398   -26759  -23354
# 4          대구광역시   -11351  -15526   -12940    -9260  -11936   -14242  -23673
# 5          인천광역시    22035    9324     9538     5777   -1670      -67   -2337
# 6          광주광역시    -2592   -2977    -9272    -7898   -8118    -6216   -3875
# 7          대전광역시      311   -8838   -20616   -10631  -16175   -14753  -16342
# 8          울산광역시     2307    2786      -80    -7622  -11917   -12654  -10172
# 9        세종특별자치시     8696   33456    53044    29816   34690    31433   23724
# 10           경기도    74131   57396    94768   133617  116162   170094  134666
# 11           강원도     2986    2085     4773     1892    2035    -3854    1661
# 12          충청북도     3113    2367     1438     5011    2262     5149    2565
# ...

# %%
pop.set_index("행정구역(시군구)별(1)",inplace=True)
pop
# Out:
#                   2013    2014     2015     2016    2017     2018    2019  \
# 행정구역(시군구)별(1)
# 서울특별시          -100550  -87831  -137256  -140257  -98486  -110230  -49588
# 부산광역시           -17710  -15092   -13560   -21392  -28398   -26759  -23354
# 대구광역시           -11351  -15526   -12940    -9260  -11936   -14242  -23673
# 인천광역시            22035    9324     9538     5777   -1670      -67   -2337
# 광주광역시            -2592   -2977    -9272    -7898   -8118    -6216   -3875
# 대전광역시              311   -8838   -20616   -10631  -16175   -14753  -16342
# 울산광역시             2307    2786      -80    -7622  -11917   -12654  -10172
# 세종특별자치시           8696   33456    53044    29816   34690    31433   23724
# 경기도              74131   57396    94768   133617  116162   170094  134666
# 강원도               2986    2085     4773     1892    2035    -3854    1661
# 충청북도              3113    2367     1438     5011    2262     5149    2565
# ...

# %%
pop.T
# Out:
# 행정구역(시군구)별(1)    서울특별시   부산광역시   대구광역시   인천광역시  광주광역시   대전광역시   울산광역시 세종특별자치시  \
# 2013           -100550  -17710  -11351   22035  -2592     311    2307    8696
# 2014            -87831  -15092  -15526    9324  -2977   -8838    2786   33456
# 2015           -137256  -13560  -12940    9538  -9272  -20616     -80   53044
# 2016           -140257  -21392   -9260    5777  -7898  -10631   -7622   29816
# 2017            -98486  -28398  -11936   -1670  -8118  -16175  -11917   34690
# 2018           -110230  -26759  -14242     -67  -6216  -14753  -12654   31433
# 2019            -49588  -23354  -23673   -2337  -3875  -16342  -10172   23724
# 2020            -64850  -14347  -16835  -15748  -6083  -11097  -13584   13025
# 2021           -106243  -18903  -24319   11423  -5883   -8931  -13674   14085
# 2022            -35340  -13562  -11519   28101  -7642   -2996   -9536   10128
#
# 행정구역(시군구)별(1)     경기도    강원도  충청북도   충청남도    전라북도   전라남도    경상북도    경상남도  \
# ...

# %%
study
# Out:
#        시점       지역  사설학원수  대학교_숫자  중학생인원수변화  초등학생인원수변화  고등학생인원수변화  유치원원아수변화  \
# 102  2013      경기도  18134      62    458220     739619     460580    182231
# 103  2013    서울특별시  13405      48    304251     469392     334123     92400
# 104  2013     경상남도   5662      20    124566     190166     122060     50370
# 105  2013    부산광역시   4638      22    110454     160821     105310     44217
# 106  2013    대구광역시   3639      11     94394     136309     103666     34550
# ..    ...      ...    ...     ...       ...        ...        ...       ...
# 233  2020     충청북도   2232      17     41458      85135      42488     16049
# 234  2020    대전광역시   2198      15     40694      79807      41549     22132
# 235  2020      강원도   2179      17     37836      73478      39806     14679
# 236  2020  제주특별자치도   1051       4     19468      40575      18679      6395
# 237  2020  세종특별자치시    689       3     12395      29487      10246      6763
#
#       대학생숫자
# 102  499221
# 103  570583
# 104  129823
# ...

# %% [markdown]
# ---
# ### 임금_병원_기업_주택 총합 csv를 불러오기

# %%
hab = pd.read_csv("../../Data/companies/총합_임금_병원_기업_주택.csv")
hab.head()
hab.loc[:,["시도별","시도","시점","년도"]]
# Out:
#          시도별       시도    시점    년도
# 0      서울특별시    서울특별시  2013  2013
# 1      부산광역시    부산광역시  2013  2013
# 2      대구광역시    대구광역시  2013  2013
# 3      인천광역시    인천광역시  2013  2013
# 4      광주광역시    광주광역시  2013  2013
# ..       ...      ...   ...   ...
# 131     전라북도     전라북도  2020  2020
# 132     전라남도     전라남도  2020  2020
# 133     경상북도     경상북도  2020  2020
# 134     경상남도     경상남도  2020  2020
# 135  제주특별자치도  제주특별자치도  2020  2020
#
# [136 rows x 4 columns]

# %% [markdown]
# > hab 데이터의 중복 컬럼이 있는 것을 발견

# %%
hab.시도별.unique()
# Out:
# array(['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
#        '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도',
#        '경상남도', '제주특별자치도'], dtype=object)

# %%
hab.시도.unique()
# Out:
# array(['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
#        '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도',
#        '경상남도', '제주특별자치도'], dtype=object)

# %%
hab.년도.unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %%
hab.시점.unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %% [markdown]
# ---
# ### hab데이터의 시도별 시점 컬럼을 제거하고 시도, 년도을 남겨 통합.

# %%
hab = hab.drop(columns=["시도별","시점"])
hab.columns
# Out:
# Index(['의원', '병원', '종합병원', '상급종합병원', '의사', '치과의사', '한의사', '약사', '간호사',
#        '기타보건의료인', '년도', '시도', '총 인구', '남성 인구', '여성 인구', '주택수', '빈집수',
#        '자동차등록대수', '전입인구', '전출인구', '활동', '신생', '소멸', '상용_월평균_임금', '임금상승률',
#        '협회 및 단체, 수리 및 기타 개인서비스업_활동', '협회 및 단체, 수리 및 기타 개인서비스업_신생',
#        '협회 및 단체, 수리 및 기타 개인서비스업_소멸', '예술, 스포츠 및 여가관련 서비스업_활동',
#        '예술, 스포츠 및 여가관련 서비스업_신생', '예술, 스포츠 및 여가관련 서비스업_소멸',
#        '보건업 및 사회복지 서비스업_활동', '보건업 및 사회복지 서비스업_신생', '보건업 및 사회복지 서비스업_소멸',
#        '교육서비스업_활동', '교육서비스업_신생', '교육서비스업_소멸', '사업 시설관리, 사업지원 및 임대 서비스업_활동',
#        '사업 시설관리, 사업지원 및 임대 서비스업_신생', '사업 시설관리, 사업지원 및 임대 서비스업_소멸',
#        '전문, 과학 및 기술서비스업_활동', '전문, 과학 및 기술서비스업_신생', '전문, 과학 및 기술서비스업_소멸',
#        '부동산업_활동', '부동산업_신생', '부동산업_소멸', '금융 및 보험업_활동', '금융 및 보험업_신생',
#        '금융 및 보험업_소멸', '정보통신업_활동', '정보통신업_신생', '정보통신업_소멸', '숙박 및 음식점업_활동',
#        '숙박 및 음식점업_신생', '숙박 및 음식점업_소멸', '운수 및 창고업_활동', '운수 및 창고업_신생',
# ...

# %% [markdown]
# > study의 시점, 지역컬럼을 년도, 시도로 바꾸기

# %%
study = study.rename(columns={"시점":"년도","지역":"시도"})
study
# Out:
#        년도       시도  사설학원수  대학교_숫자  중학생인원수변화  초등학생인원수변화  고등학생인원수변화  유치원원아수변화  \
# 102  2013      경기도  18134      62    458220     739619     460580    182231
# 103  2013    서울특별시  13405      48    304251     469392     334123     92400
# 104  2013     경상남도   5662      20    124566     190166     122060     50370
# 105  2013    부산광역시   4638      22    110454     160821     105310     44217
# 106  2013    대구광역시   3639      11     94394     136309     103666     34550
# ..    ...      ...    ...     ...       ...        ...        ...       ...
# 233  2020     충청북도   2232      17     41458      85135      42488     16049
# 234  2020    대전광역시   2198      15     40694      79807      41549     22132
# 235  2020      강원도   2179      17     37836      73478      39806     14679
# 236  2020  제주특별자치도   1051       4     19468      40575      18679      6395
# 237  2020  세종특별자치시    689       3     12395      29487      10246      6763
#
#       대학생숫자
# 102  499221
# 103  570583
# 104  129823
# ...

# %%
hab_study = pd.merge(study,hab,on=("년도","시도"))

# %%
hab_study.head(1)
# Out:
#      년도   시도  사설학원수  대학교_숫자  중학생인원수변화  초등학생인원수변화  고등학생인원수변화  유치원원아수변화   대학생숫자  \
# 0  2013  경기도  18134      62    458220     739619     460580    182231  499221
#
#      의원  ...  수도, 하수 및 폐기물처리, 원료재생업_소멸  전기, 가스, 증기 및 공기조절 공급업_활동  \
# 0  5876  ...                       189                       310
#
#    전기, 가스, 증기 및 공기조절 공급업_신생  전기, 가스, 증기 및 공기조절 공급업_소멸  제조업_활동  제조업_신생  제조업_소멸  \
# 0                        91                        13  150356   16149   12398
#
#    광업_활동  광업_신생  광업_소멸
# 0    104      9     10
#
# [1 rows x 83 columns]

# %%
sanghyuck = pd.read_csv("../../Data/sanghyuk/mergedEtc.csv",index_col=0)
sanghyuck.head(1)
# Out:
#      년도     시도      총 인구    남성 인구    여성 인구  부채  자산(만원)     농가수  어가수  백화점판매액  \
# 0  2013  서울특별시  10143645  5007869  5135776 NaN     NaN  2826.0  NaN     NaN
#
#    대형소매점  예금은행대출금액       예금액         지방세
# 0    NaN  462443.1  532689.2  12980600.0

# %% [markdown]
# > 부채, 자산 컬럼의 경우 2017년 이후 데이터만 존재하여 NAN이 다수 있음.
#  이를 0으로 처리하기에는 부채가 0이다가 2017년도에 갑자기 생겨나는건 말이안됨.
#  따라서 일단 병합을 할 것이나. 이후 컬럼의 존속여부를 토론해야 할 것으로 보임.
# > 어가 컬럼의 경우는 NAN데이터가 존재하나 이는 서울이나 대구등 내륙지방이므로 0으로 처리해도 될듯함.
# > 백화점,대형소매점 컬럼은 2015년 부터 데이터가 존재하며 백화점이 없는 (강원,충청,전라,경북)

# %%
sanghyuck.columns
# Out:
# Index(['년도', '시도', '총 인구', '남성 인구', '여성 인구', '부채', '자산(만원)', '농가수', '어가수',
#        '백화점판매액', '대형소매점', '예금은행대출금액', '예금액', '지방세'],
#       dtype='object')

# %%
hab_study_gdp = pd.merge(hab_study,sanghyuck,on=["년도","시도"])
hab_study_gdp.head()
# Out:
#      년도     시도  사설학원수  대학교_숫자  중학생인원수변화  초등학생인원수변화  고등학생인원수변화  유치원원아수변화  \
# 0  2013    경기도  18134      62    458220     739619     460580    182231
# 1  2013  서울특별시  13405      48    304251     469392     334123     92400
# 2  2013   경상남도   5662      20    124566     190166     122060     50370
# 3  2013  부산광역시   4638      22    110454     160821     105310     44217
# 4  2013  대구광역시   3639      11     94394     136309     103666     34550
#
#     대학생숫자    의원  ...  여성 인구_y  부채  자산(만원)       농가수     어가수  백화점판매액  대형소매점  \
# 0  499221  5876  ...  6075437 NaN     NaN  133012.0   853.0     NaN    NaN
# 1  570583  7505  ...  5135776 NaN     NaN    2826.0     NaN     NaN    NaN
# 2  129823  1481  ...  1655228 NaN     NaN  136708.0  9346.0     NaN    NaN
# 3  274955  2119  ...  1780635 NaN     NaN    7178.0  2061.0     NaN    NaN
# 4  130792  1576  ...  1255517 NaN     NaN   17717.0     NaN     NaN    NaN
#
#    예금은행대출금액       예금액         지방세
# 0  248468.3   13718.5  13301235.0
# ...

# %%
hab_study_gdp.columns
# Out:
# Index(['년도', '시도', '사설학원수', '대학교_숫자', '중학생인원수변화', '초등학생인원수변화', '고등학생인원수변화',
#        '유치원원아수변화', '대학생숫자', '의원', '병원', '종합병원', '상급종합병원', '의사', '치과의사', '한의사',
#        '약사', '간호사', '기타보건의료인', '총 인구_x', '남성 인구_x', '여성 인구_x', '주택수', '빈집수',
#        '자동차등록대수', '전입인구', '전출인구', '활동', '신생', '소멸', '상용_월평균_임금', '임금상승률',
#        '협회 및 단체, 수리 및 기타 개인서비스업_활동', '협회 및 단체, 수리 및 기타 개인서비스업_신생',
#        '협회 및 단체, 수리 및 기타 개인서비스업_소멸', '예술, 스포츠 및 여가관련 서비스업_활동',
#        '예술, 스포츠 및 여가관련 서비스업_신생', '예술, 스포츠 및 여가관련 서비스업_소멸',
#        '보건업 및 사회복지 서비스업_활동', '보건업 및 사회복지 서비스업_신생', '보건업 및 사회복지 서비스업_소멸',
#        '교육서비스업_활동', '교육서비스업_신생', '교육서비스업_소멸', '사업 시설관리, 사업지원 및 임대 서비스업_활동',
#        '사업 시설관리, 사업지원 및 임대 서비스업_신생', '사업 시설관리, 사업지원 및 임대 서비스업_소멸',
#        '전문, 과학 및 기술서비스업_활동', '전문, 과학 및 기술서비스업_신생', '전문, 과학 및 기술서비스업_소멸',
#        '부동산업_활동', '부동산업_신생', '부동산업_소멸', '금융 및 보험업_활동', '금융 및 보험업_신생',
#        '금융 및 보험업_소멸', '정보통신업_활동', '정보통신업_신생', '정보통신업_소멸', '숙박 및 음식점업_활동',
# ...

# %% [markdown]
# ---
# ### 중복되는 인구 데이터 없애기

# %%
hab_study_gdp.loc[:,["총 인구_x","총 인구_y","남성 인구_x","남성 인구_y","여성 인구_x","여성 인구_y"]]
# Out:
#        총 인구_x    총 인구_y  남성 인구_x  남성 인구_y  여성 인구_x  여성 인구_y
# 0    12234630  12234630  6159193  6159193  6075437  6075437
# 1    10143645  10143645  5007869  5007869  5135776  5135776
# 2     3333820   3333820  1678592  1678592  1655228  1655228
# 3     3527635   3527635  1747000  1747000  1780635  1780635
# 4     2501588   2501588  1246071  1246071  1255517  1255517
# ..        ...       ...      ...      ...      ...      ...
# 131   1600837   1600837   811591   811591   789246   789246
# 132   1463882   1463882   730699   730699   733183   733183
# 133   1542840   1542840   776505   776505   766335   766335
# 134    674635    674635   338609   338609   336026   336026
# 135    355831    355831   177568   177568   178263   178263
#
# [136 rows x 6 columns]

# %%
hab_study_gdp = hab_study_gdp.drop(columns=["총 인구_x","남성 인구_x","여성 인구_x"])

# %%
hab_study_gdp.columns
hab_study_gdp = hab_study_gdp.rename(columns={"총 인구_y":"총_인구","남성 인구_y":"남성_인구","여성 인구_y":"여성_인구"})

# %% [markdown]
# ---
# # 데이터 병합 결과
# row 136
# col 90
# 년도 2013~2020
# 지역 대한민국 시.도

# %%
hab_study_gdp.shape
# row 136, col 90
# Out:
# (136, 92)

# %%
hab_study_gdp.년도.unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %%
hab_study_gdp.to_csv("../../Data/study/총합_교육_임금_병원_기업_주택.csv",index=False)

# %%
hab_study_gdp.to_csv("../../Data/00.통합.csv",index=False)

# %%
hab_study_gdp.columns
# Out:
# Index(['년도', '시도', '사설학원수', '대학교_숫자', '중학생인원수변화', '초등학생인원수변화', '고등학생인원수변화',
#        '유치원원아수변화', '대학생숫자', '의원', '병원', '종합병원', '상급종합병원', '의사', '치과의사', '한의사',
#        '약사', '간호사', '기타보건의료인', '주택수', '빈집수', '자동차등록대수', '전입인구', '전출인구', '활동',
#        '신생', '소멸', '상용_월평균_임금', '임금상승률', '협회 및 단체, 수리 및 기타 개인서비스업_활동',
#        '협회 및 단체, 수리 및 기타 개인서비스업_신생', '협회 및 단체, 수리 및 기타 개인서비스업_소멸',
#        '예술, 스포츠 및 여가관련 서비스업_활동', '예술, 스포츠 및 여가관련 서비스업_신생',
#        '예술, 스포츠 및 여가관련 서비스업_소멸', '보건업 및 사회복지 서비스업_활동', '보건업 및 사회복지 서비스업_신생',
#        '보건업 및 사회복지 서비스업_소멸', '교육서비스업_활동', '교육서비스업_신생', '교육서비스업_소멸',
#        '사업 시설관리, 사업지원 및 임대 서비스업_활동', '사업 시설관리, 사업지원 및 임대 서비스업_신생',
#        '사업 시설관리, 사업지원 및 임대 서비스업_소멸', '전문, 과학 및 기술서비스업_활동',
#        '전문, 과학 및 기술서비스업_신생', '전문, 과학 및 기술서비스업_소멸', '부동산업_활동', '부동산업_신생',
#        '부동산업_소멸', '금융 및 보험업_활동', '금융 및 보험업_신생', '금융 및 보험업_소멸', '정보통신업_활동',
#        '정보통신업_신생', '정보통신업_소멸', '숙박 및 음식점업_활동', '숙박 및 음식점업_신생', '숙박 및 음식점업_소멸',
# ...
