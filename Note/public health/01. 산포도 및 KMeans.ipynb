# %%
import pandas as pd
# import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import json
import folium
warnings.filterwarnings("ignore")
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
public_health = pd.read_csv('../../Data/public health/public_health10_21.csv', index_col='시도별')
public_health.head()
# Out:
#          의원   병원  종합병원  상급종합병원  의사  치과의사  한의사  약사  간호사  기타보건의료인    시점
# 시도별
# 서울특별시  7142  167    42      17 NaN   NaN  NaN NaN  NaN      NaN  2009
# 부산광역시  2065  103    22       4 NaN   NaN  NaN NaN  NaN      NaN  2009
# 대구광역시  1460   98     7       4 NaN   NaN  NaN NaN  NaN      NaN  2009
# 인천광역시  1313   50    12       2 NaN   NaN  NaN NaN  NaN      NaN  2009
# 광주광역시   826   49    17       2 NaN   NaN  NaN NaN  NaN      NaN  2009

# %%
public_health['시점'].unique()
# Out:
# array([2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020, 2021, 2022])

# %%
public_health[public_health['시점'] == 2010]
#[['의원', '병원', '종합병원', '상급종합병원']]
#[['의사', '치과의사', '한의사', '약사', '간호사','기타보건의료인']]
# Out:
#            의원   병원  종합병원  상급종합병원       의사    치과의사     한의사      약사      간호사  \
# 시도별
# 서울특별시    7328  171    42      17  23077.0  5933.0  3937.0  7667.0  28634.0
# 부산광역시    2071  109    24       4   6247.0  1300.0  1134.0  2194.0   9268.0
# 대구광역시    1496  101     8       4   4597.0  1055.0   840.0  1679.0   6143.0
# 인천광역시    1321   55    12       2   3212.0   874.0   606.0  1356.0   4364.0
# 광주광역시     839   53    19       2   2723.0   783.0   393.0   951.0   4538.0
# 대전광역시     957   35     6       2   2910.0   587.0   545.0   978.0   3874.0
# 울산광역시     532   37     4       0   1262.0   396.0   306.0   540.0   2192.0
# 경기도      5598  253    49       5  14288.0  3930.0  2716.0  6101.0  18406.0
# 강원도       667   45    13       2   2254.0   557.0   425.0   820.0   3966.0
# 충청북도      769   39     9       1   1959.0   435.0   450.0   863.0   2589.0
# 충청남도     1021   54     9       2   2506.0   720.0   604.0  1094.0   3264.0
# 전라북도     1051   66    12       2   2967.0   724.0   684.0  1180.0   4356.0
# 전라남도      889   75    20       0   2534.0   586.0   524.0  1075.0   5173.0
# 경상북도     1169   77    18       0   2995.0   700.0   767.0  1306.0   5732.0
# 경상남도     1457  140    23       1   4011.0   926.0   858.0  1471.0   6427.0
# 제주특별자치도   304    5     6       0    783.0   172.0   142.0   299.0   1751.0
#
#          기타보건의료인    시점
# 시도별
# 서울특별시     4553.0  2010
# 부산광역시     1894.0  2010
# 대구광역시     1280.0  2010
# 인천광역시     1375.0  2010
# 광주광역시      870.0  2010
# 대전광역시     1002.0  2010
# 울산광역시      499.0  2010
# 경기도       5302.0  2010
# 강원도        742.0  2010
# 충청북도       867.0  2010
# 충청남도      1166.0  2010
# 전라북도      1241.0  2010
# 전라남도      1474.0  2010
# 경상북도      1361.0  2010
# 경상남도      1630.0  2010
# 제주특별자치도    348.0  2010

# %%
public_health.iloc[:,0:10]
# Out:
#            의원   병원  종합병원  상급종합병원  의사  치과의사  한의사  약사  간호사  기타보건의료인
# 시도별
# 서울특별시    7142  167    42      17 NaN   NaN  NaN NaN  NaN      NaN
# 부산광역시    2065  103    22       4 NaN   NaN  NaN NaN  NaN      NaN
# 대구광역시    1460   98     7       4 NaN   NaN  NaN NaN  NaN      NaN
# 인천광역시    1313   50    12       2 NaN   NaN  NaN NaN  NaN      NaN
# 광주광역시     826   49    17       2 NaN   NaN  NaN NaN  NaN      NaN
# ...       ...  ...   ...     ...  ..   ...  ...  ..  ...      ...
# 전라북도     1190   62    12       2 NaN   NaN  NaN NaN  NaN      NaN
# 전라남도      958   73    25       1 NaN   NaN  NaN NaN  NaN      NaN
# 경상북도     1296   56    20       0 NaN   NaN  NaN NaN  NaN      NaN
# 경상남도     1703  132    23       3 NaN   NaN  NaN NaN  NaN      NaN
# 제주특별자치도   471    7     6       0 NaN   NaN  NaN NaN  NaN      NaN
#
# [235 rows x 10 columns]

# %%
df = public_health[public_health['시점'] == 2020].iloc[:,0:10]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df[4]
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 4

# %%
df[df.index=='경기도']
# Out:
#        의원   병원  종합병원  상급종합병원       의사    치과의사     한의사      약사      간호사  \
# 시도별
# 경기도  5598  253    49       5  14288.0  3930.0  2716.0  6101.0  18406.0
#
#      기타보건의료인    시점
# 시도별
# 경기도   5302.0  2010

# %%
# plt.style.use('ggplot')
plt.style.use('default')

df = public_health[public_health['시점'] == 2020].iloc[:,0:10]
df.plot(
    kind='scatter',
    x = df['병원'],
    y = df['의사'],
    c = 'coral',
    figsize=(15,10)
)
plt.xlabel('4')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 5
#       2 plt.style.use('default')
#       4 df = public_health[public_health['시점'] == 2020].iloc[:,0:10]
# ----> 5 df.plot(
#       6     kind='scatter',
#       7     x = df['병원'],
#       8     y = df['의사'],
#       9     c = 'coral',
#      10     figsize=(15,10)
#      11 )
#      12 plt.xlabel('4')
#      13 plt.show()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/plotting/_core.py:945, in PlotAccessor.__call__(self, *args, **kwargs)
#     943 if kind in self._dataframe_kinds:
#     944     if isinstance(data, ABCDataFrame):
# --> 945         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     946     else:
#     947         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:452, in MPLPlot.generate(self)
#     450 self._compute_plot_data()
#     451 self._setup_subplots()
# --> 452 self._make_plot()
#     453 self._add_table()
#     454 self._make_legend()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1260, in ScatterPlot._make_plot(self)
#    1257 else:
#    1258     label = None
#    1259 scatter = ax.scatter(
# -> 1260     data[x].values,
#    1261     data[y].values,
#    1262     c=c_values,
#    1263     label=label,
#    1264     cmap=cmap,
#    1265     norm=norm,
#    1266     **self.kwds,
#    1267 )
#    1268 if cb:
#    1269     cbar_label = c if c_is_column else ""
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Int64Index([230, 145, 109, 68, 85, 50, 38, 2, 288, 45, 38, 45, 73, 79, 73, 140,\n            7],\n           dtype='int64')] are in the [columns]"

# %%
# df = public_health[public_health['시점'] == year][['의원', '병원', '종합병원', '상급종합병원']]
df = public_health[public_health['시점'] == 2010]
df[4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 3
#       1 # df = public_health[public_health['시점'] == year][['의원', '병원', '종합병원', '상급종합병원']]
#       2 df = public_health[public_health['시점'] == 2010]
# ----> 3 df[4]
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 4

# %%
plt.style.use('default')
years = [year for year in range(2020,2023)]
# years = [year for year in range(2009,2023)]
for year in years:
    df = public_health[public_health['시점'] == year][['의원', '병원', '종합병원', '상급종합병원']]
    df.plot(
    kind='scatter',
    x = df.index,
    y = df,
    # c = 'coral',
    # s = 10, #산점도 점의 크기 
    # s = cylinder_size, #산점도 점의 크기 300은 넘 크다 100으로 줄여야지
    figsize=(15,10)
)
    plt.show()
# plt.title('역상관을 잘 띄고 있따')
# plt.xlabel('4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 6
#       4 for year in years:
#       5     df = public_health[public_health['시점'] == year][['의원', '병원', '종합병원', '상급종합병원']]
# ----> 6     df.plot(
#       7     kind='scatter',
#       8     # x = 4,
#       9     # y = 0,
#      10     # c = 'coral',
#      11     # s = 10, #산점도 점의 크기
#      12     # s = cylinder_size, #산점도 점의 크기 300은 넘 크다 100으로 줄여야지
#      13     figsize=(15,10)
#      14 )
#      15     plt.show()
#      16 # plt.title('역상관을 잘 띄고 있따')
#      17 # plt.xlabel('4')
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/plotting/_core.py:945, in PlotAccessor.__call__(self, *args, **kwargs)
#     943 if kind in self._dataframe_kinds:
#     944     if isinstance(data, ABCDataFrame):
# --> 945         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     946     else:
#     947         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:70, in plot(data, kind, **kwargs)
#      68             ax = plt.gca()
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      71 plot_obj.generate()
#      72 plot_obj.draw()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1196, in ScatterPlot.__init__(self, data, x, y, s, c, **kwargs)
#    1194 elif is_hashable(s) and s in data.columns:
#    1195     s = data[s]
# -> 1196 super().__init__(data, x, y, s=s, **kwargs)
#    1197 if is_integer(c) and not self.data.columns.holds_integer():
#    1198     c = self.data.columns[c]
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1137, in PlanePlot.__init__(self, data, x, y, **kwargs)
#    1135 MPLPlot.__init__(self, data, **kwargs)
#    1136 if x is None or y is None:
# -> 1137     raise ValueError(self._kind + " requires an x and y column")
#    1138 if is_integer(x) and not self.data.columns.holds_integer():
#    1139     x = self.data.columns[x]
#
# ValueError: scatter requires an x and y column
