# %%
1+2
# Out:
# 3

# %%
import pandas as pd

# %%
population = pd.read_csv("../Data/주민등록인구_시도_시_군_구__20230207113157.csv", encoding='euc-kr')
population.head()
# Out:
#    행정구역별      2013    2013.1    2013.2      2014    2014.1    2014.2  \
# 0  행정구역별     계 (명)     남 (명)     여 (명)     계 (명)     남 (명)     여 (명)
# 1     전국  51141463  25588336  25553127  51327916  25669296  25658620
# 2  서울특별시  10143645   5007869   5135776  10103233   4979768   5123465
# 3  부산광역시   3527635   1747000   1780635   3519401   1740417   1778984
# 4  대구광역시   2501588   1246071   1255517   2493264   1241119   1252145
#
#        2015    2015.1    2015.2  ...    2019.2      2020    2020.1    2020.2  \
# 0     계 (명)     남 (명)     여 (명)  ...     여 (명)     계 (명)     남 (명)     여 (명)
# 1  51529338  25758186  25771152  ...  25985045  51829023  25841029  25987994
# 2  10022181   4930943   5091238  ...   4985048   9668465   4701723   4966742
# 3   3513777   1735570   1778207  ...   1738424   3391946   1661000   1730946
# 4   2487829   1237291   1250538  ...   1232745   2418346   1193109   1225237
#
#        2021    2021.1    2021.2      2022    2022.1    2022.2
# ...

# %%
df = pd.read_csv("../Data/순이동인구_시도_시_군_구__20230207111701.csv", encoding='euc-kr')
df
# Out:
#     행정구역(시군구)별(1)     2013    2014     2015     2016    2017     2018    2019  \
# 0   행정구역(시군구)별(1)        계       계        계        계       계        계       계
# 1              전국        0       0        0        0       0        0       0
# 2           서울특별시  -100550  -87831  -137256  -140257  -98486  -110230  -49588
# 3           부산광역시   -17710  -15092   -13560   -21392  -28398   -26759  -23354
# 4           대구광역시   -11351  -15526   -12940    -9260  -11936   -14242  -23673
# 5           인천광역시    22035    9324     9538     5777   -1670      -67   -2337
# 6           광주광역시    -2592   -2977    -9272    -7898   -8118    -6216   -3875
# 7           대전광역시      311   -8838   -20616   -10631  -16175   -14753  -16342
# 8           울산광역시     2307    2786      -80    -7622  -11917   -12654  -10172
# 9         세종특별자치시     8696   33456    53044    29816   34690    31433   23724
# 10            경기도    74131   57396    94768   133617  116162   170094  134666
# ...

# %%
df = df.loc[2:]
df
# Out:
#    행정구역(시군구)별(1)     2013    2014     2015     2016    2017     2018    2019  \
# 2          서울특별시  -100550  -87831  -137256  -140257  -98486  -110230  -49588
# 3          부산광역시   -17710  -15092   -13560   -21392  -28398   -26759  -23354
# 4          대구광역시   -11351  -15526   -12940    -9260  -11936   -14242  -23673
# 5          인천광역시    22035    9324     9538     5777   -1670      -67   -2337
# 6          광주광역시    -2592   -2977    -9272    -7898   -8118    -6216   -3875
# 7          대전광역시      311   -8838   -20616   -10631  -16175   -14753  -16342
# 8          울산광역시     2307    2786      -80    -7622  -11917   -12654  -10172
# 9        세종특별자치시     8696   33456    53044    29816   34690    31433   23724
# 10           경기도    74131   57396    94768   133617  116162   170094  134666
# 11           강원도     2986    2085     4773     1892    2035    -3854    1661
# 12          충청북도     3113    2367     1438     5011    2262     5149    2565
# ...

# %%
df.reset_index(drop=True, inplace=True)
df.rename(columns={'행정구역(시군구)별(1)':'시군구'}, inplace=True)
df
# Out:
# /var/folders/bq/1n_n2kn51klbvqx57r2ykhkh0000gn/T/ipykernel_52792/742751388.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'행정구역(시군구)별(1)':'시군구'}, inplace=True)
#         시군구     2013    2014     2015     2016    2017     2018    2019  \
# 0     서울특별시  -100550  -87831  -137256  -140257  -98486  -110230  -49588
# 1     부산광역시   -17710  -15092   -13560   -21392  -28398   -26759  -23354
# 2     대구광역시   -11351  -15526   -12940    -9260  -11936   -14242  -23673
# 3     인천광역시    22035    9324     9538     5777   -1670      -67   -2337
# 4     광주광역시    -2592   -2977    -9272    -7898   -8118    -6216   -3875
# 5     대전광역시      311   -8838   -20616   -10631  -16175   -14753  -16342
# 6     울산광역시     2307    2786      -80    -7622  -11917   -12654  -10172
# ...
