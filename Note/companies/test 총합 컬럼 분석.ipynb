# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
df = pd.read_csv("../../Data/03.통합.csv")
df.head()
# Out:
#      년도     시도       총인구     전출인구    출생아수  산부인과의원수  초등학생인원수  도매 및 소매업 신생  \
# 0  2013    경기도  12234630  1821303  112129      286   739619        49143
# 1  2013  서울특별시  10143645  1620640   84066      395   469392        48097
# 2  2013   경상남도   3333820   423864   29504       65   190166        12612
# 3  2013  부산광역시   3527635   496161   25831       82   160821        13902
# 4  2013  대구광역시   2501588   363224   19340       86   136309         9981
#
#    예금은행대출금액       예금액
# 0  248468.3   13718.5
# 1  462443.1  532689.2
# 2   57288.6    6703.3
# 3   77411.6   59554.5
# 4   46578.5   37541.7

# %%
# 경기도 전출인구
gyeong = df[(df['시도'] == '경기도')].전출인구
gyeong.head()
gyeong
# Out:
# 0      1821303
# 17     1834379
# 34     1898312
# 51     1824976
# 68     1772162
# 85     1871621
# 102    1806296
# 119    1984199
# Name: 전출인구, dtype: int64

# %%
plt.plot(gyeong)
plt.title('경기도 2013 ~ 2020 전출인구')
# Out:
# Text(0.5, 1.0, '경기도 2013 ~ 2020 전출인구')

# %%
plt.plot(df[(df['시도'] == '서울특별시')].전출인구)
plt.title('서울특별시 2013 ~ 2020 전출인구')
# Out:
# Text(0.5, 1.0, '서울특별시 2013 ~ 2020 전출인구')

# %%
plt.plot(df[(df['시도'] == '강원도')].전출인구)
plt.title('강원도 2013 ~ 2020 전출인구')
# Out:
# Text(0.5, 1.0, '강원도 2013 ~ 2020 전출인구')

# %%
plt.plot(df[(df['시도'] == '서울특별시')].총인구)
plt.title('서울특별시 2013 ~ 2020 총인구')
# Out:
# Text(0.5, 1.0, '서울특별시 2013 ~ 2020 총인구')

# %%
plt.plot(df[(df['시도'] == '강원도')].총인구)
plt.title('강원도 2013 ~ 2020 총인구')
# Out:
# Text(0.5, 1.0, '강원도 2013 ~ 2020 총인구')
