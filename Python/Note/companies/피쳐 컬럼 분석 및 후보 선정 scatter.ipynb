# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
df = pd.read_csv("../../Data/00.통합.csv")
df.columns
# Out:
# Index(['년도', '시도', '사설학원수', '대학교_숫자', '중학생인원수변화', '초등학생인원수변화', '고등학생인원수변화',
#        '유치원원아수변화', '대학생숫자', '의원', '병원', '종합병원', '상급종합병원', '의사', '치과의사', '한의사',
#        '약사', '간호사', '기타보건의료인', '주택수', '빈집수', '자동차등록대수', '전입인구', '전출인구', '활동',
#        '신생', '소멸', '상용_월평균_임금', '임금상승률', '협회 및 단체, 수리 및 기타 개인서비스업_활동',
#        '협회 및 단체, 수리 및 기타 개인서비스업_신생', '협회 및 단체, 수리 및 기타 개인서비스업_소멸',
#        '예술, 스포츠 및 여가관련 서비스업_활동', '예술, 스포츠 및 여가관련 서비스업_신생',
#        '예술, 스포츠 및 여가관련 서비스업_소멸', '보건업 및 사회복지 서비스업_활동', '보건업 및 사회복지 서비스업_신생',
#        '보건업 및 사회복지 서비스업_소멸', '교육서비스업_활동', '교육서비스업_신생', '교육서비스업_소멸',
#        '사업 시설관리, 사업지원 및 임대 서비스업_활동', '사업 시설관리, 사업지원 및 임대 서비스업_신생',
#        '사업 시설관리, 사업지원 및 임대 서비스업_소멸', '전문, 과학 및 기술서비스업_활동',
#        '전문, 과학 및 기술서비스업_신생', '전문, 과학 및 기술서비스업_소멸', '부동산업_활동', '부동산업_신생',
#        '부동산업_소멸', '금융 및 보험업_활동', '금융 및 보험업_신생', '금융 및 보험업_소멸', '정보통신업_활동',
#        '정보통신업_신생', '정보통신업_소멸', '숙박 및 음식점업_활동', '숙박 및 음식점업_신생', '숙박 및 음식점업_소멸',
# ...

# %%
df1 = pd.read_csv("../../Data/01.통합.csv", index_col=0)
df1.columns
# Out:
# Index(['년도', '시도', '초등학생인원수', '빈집수', '전출인구', '총인구', '예금은행대출금액', '예금액',
#        '산부인과의원수', '협회 및 단체, 수리 및 기타 개인서비스업 소멸', '도매 및 소매업 신생', '교육서비스업 소멸'],
#       dtype='object')

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=7,figsize=(30,5))
sns.scatterplot(x="전출인구", y="활동", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="소멸", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_활동", data=df, ax=ax[3])
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[4])
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_소멸", data=df, ax=ax[5])
# sns.scatterplot(x="전출인구", y="대학생숫자", data=df, ax=ax[6])
plt.show()

# %% [markdown]
# - 신생 > 활동 > 소멸
# - 협회 및 단체, 수리 및 기타 개인서비스업_신생

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="부동산업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="부동산업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="부동산업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="예술, 스포츠 및 여가관련 서비스업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="예술, 스포츠 및 여가관련 서비스업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="예술, 스포츠 및 여가관련 서비스업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="보건업 및 사회복지 서비스업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="보건업 및 사회복지 서비스업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="보건업 및 사회복지 서비스업_소멸", data=df, ax=ax[3])
plt.show()

# %% [markdown]
# > xx

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(y="전출인구", x="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(y="전출인구", x="교육서비스업_활동", data=df, ax=ax[1])
sns.scatterplot(y="전출인구", x="교육서비스업_신생", data=df, ax=ax[2])
sns.scatterplot(y="전출인구", x="교육서비스업_소멸", data=df, ax=ax[3])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 7
#       5 sns.scatterplot(y="전출인구", x="교육서비스업_신생", data=df, ax=ax[2])
#       6 sns.scatterplot(y="전출인구", x="교육서비스업_소멸", data=df, ax=ax[3])
# ----> 7 plt.xlabel(fontsize=15)
#       8 plt.show()
#
# TypeError: xlabel() missing 1 required positional argument: 'xlabel'

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="사업 시설관리, 사업지원 및 임대 서비스업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="사업 시설관리, 사업지원 및 임대 서비스업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="사업 시설관리, 사업지원 및 임대 서비스업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="전문, 과학 및 기술서비스업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="전문, 과학 및 기술서비스업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="전문, 과학 및 기술서비스업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="금융 및 보험업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="금융 및 보험업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="금융 및 보험업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="정보통신업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="정보통신업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="정보통신업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="숙박 및 음식점업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="숙박 및 음식점업_활동", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="숙박 및 음식점업_활동", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="운수 및 창고업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="운수 및 창고업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="운수 및 창고업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="도매 및 소매업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="도매 및 소매업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="도매 및 소매업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="건설업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="건설업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="건설업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="건설업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="건설업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="건설업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="수도, 하수 및 폐기물처리, 원료재생업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="수도, 하수 및 폐기물처리, 원료재생업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="수도, 하수 및 폐기물처리, 원료재생업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="전기, 가스, 증기 및 공기조절 공급업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="전기, 가스, 증기 및 공기조절 공급업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="전기, 가스, 증기 및 공기조절 공급업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="제조업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="제조업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="제조업_소멸", data=df, ax=ax[3])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_신생", data=df, ax=ax[0])
sns.scatterplot(x="전출인구", y="광업_활동", data=df, ax=ax[1])
sns.scatterplot(x="전출인구", y="광업_신생", data=df, ax=ax[2])
sns.scatterplot(x="전출인구", y="광업_소멸", data=df, ax=ax[3])
plt.show()

# %% [markdown]
# ---

# %%
fig = plt.figure(figsize=(15,10))
ax1=fig.add_subplot(2,3,1)
ax2=fig.add_subplot(2,3,2)
ax3=fig.add_subplot(2,3,3)
# df.plot(
#     kind='scatter',
#     x = 4,
#     y = 0,
#     c='blue',
#     s=cylinder_size, #점의 크기
#     alpha=0.3, #투명도
#     figsize=(10,5)
# )

# plt.show()

sns.scatterplot(x="도매 및 소매업_신생", y="전출인구", alpha=0.3, s=150,  data=df, ax=ax1)
sns.scatterplot(x="협회 및 단체, 수리 및 기타 개인서비스업_소멸", alpha=0.3, s=150, y="전출인구", data=df, ax=ax2)
sns.scatterplot(x="교육서비스업_소멸", y="전출인구", alpha=0.3, s=150, data=df, ax=ax3)

# ax1.set_ylabel("")
# ax2.set_ylabel("")
# ax3.set_ylabel("")

ax1.set_title('도매 및 소매 신생 기업 수', fontsize=20)
ax2.set_title('협회 및 단체, 수리 및 기타 개인서비스업 소멸 기업 수', fontsize=12)
ax3.set_title('교육서비스업 소멸 기업 수', fontsize=20)

plt.show()

# %% [markdown]
# > 도매 및 소매업_신생 > 협회 및 단체, 수리 및 기타 개인서비스업_소멸 > 교육서비스업_소멸

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=5,figsize=(30,5))
sns.scatterplot(x="전출인구", y="도매 및 소매업_신생", data=df, ax=ax[0])
sns.scatterplot(x="총_인구", y="도매 및 소매업_신생", data=df, ax=ax[1])
sns.scatterplot(x="전입인구", y="도매 및 소매업_신생", data=df, ax=ax[2])
sns.scatterplot(x="초등학생인원수변화", y="도매 및 소매업_신생", data=df, ax=ax[3])
sns.scatterplot(x="빈집수", y="도매 및 소매업_신생", data=df, ax=ax[4])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=5,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_소멸", data=df, ax=ax[0])
sns.scatterplot(x="총_인구", y="협회 및 단체, 수리 및 기타 개인서비스업_소멸", data=df, ax=ax[1])
# sns.scatterplot(x="전입인구", y="협회 및 단체, 수리 및 기타 개인서비스업_소멸", data=df, ax=ax[2])
sns.scatterplot(x="초등학생인원수변화", y="협회 및 단체, 수리 및 기타 개인서비스업_소멸", data=df, ax=ax[3])
sns.scatterplot(x="빈집수", y="협회 및 단체, 수리 및 기타 개인서비스업_소멸", data=df, ax=ax[4])
plt.show()

# %%
plt.figure(figsize=(25,15))
fig, ax = plt.subplots(ncols=4,figsize=(30,5))
sns.scatterplot(x="전출인구", y="협회 및 단체, 수리 및 기타 개인서비스업_소멸", data=df, ax=ax[0])
sns.scatterplot(x="총_인구", y="협회 및 단체, 수리 및 기타 개인서비스업_소멸", data=df, ax=ax[1])
sns.scatterplot(x="초등학생인원수변화", y="협회 및 단체, 수리 및 기타 개인서비스업_소멸", data=df, ax=ax[2])
sns.scatterplot(x="빈집수", y="협회 및 단체, 수리 및 기타 개인서비스업_소멸", data=df, ax=ax[3])
plt.show()

# %%
sns.pairplot(
    df,
    vars=['전출인구', '총_인구',\
        '초등학생인원수변화', '유치원원아수변화', \
        '협회 및 단체, 수리 및 기타 개인서비스업_소멸', '도매 및 소매업_신생', '교육서비스업_소멸',\
        '예금액', '예금은행대출금액'],
    kind='reg',
)
plt.show()

# %%
df['빈집수'].isna().sum()
# Out:
# 34
