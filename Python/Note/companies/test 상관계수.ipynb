# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 

warnings.filterwarnings('ignore')

# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
pay = pd.read_csv("../../Data/companies/정제_월평균임금_임금상승률(2013~2022).csv")
industries = pd.read_csv("../../Data/companies/정제_업종_전부(2013~2020).csv")
companies = pd.read_csv("../../Data/companies/정제_시도별_전체_기업수(2013~2020).csv")

# %%
pay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시도         170 non-null    object
#  1   년도         170 non-null    int64
#  2   상용_월평균_임금  170 non-null    float64
#  3   임금상승률      170 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 5.4+ KB

# %%
len(pay)
# Out:
# 170

# %%
len(companies)
# Out:
# 136

# %%
pd.concat([pay, companies], axis=1)
# Out:
#           시도    년도  상용_월평균_임금  임금상승률     시도      년도         활동        신생  \
# 0      서울특별시  2013  3168798.0    5.4  서울특별시  2013.0  1258829.0  168425.0
# 1      부산광역시  2013  2520222.0    2.7  부산광역시  2013.0   370922.0   49110.0
# 2      대구광역시  2013  2315945.0    2.3  대구광역시  2013.0   255803.0   33186.0
# 3      인천광역시  2013  2609457.0    4.0  인천광역시  2013.0   278236.0   41563.0
# 4      광주광역시  2013  2417477.0    4.2  광주광역시  2013.0   142802.0   22274.0
# ..       ...   ...        ...    ...    ...     ...        ...       ...
# 165     전라북도  2022  3192759.0    3.6    NaN     NaN        NaN       NaN
# 166     전라남도  2022  3445263.0    2.8    NaN     NaN        NaN       NaN
# 167     경상북도  2022  3563537.0    3.2    NaN     NaN        NaN       NaN
# 168     경상남도  2022  3560180.0    4.7    NaN     NaN        NaN       NaN
# 169  제주특별자치도  2022  3036703.0    4.5    NaN     NaN        NaN       NaN
#
#            소멸
# 0    150812.0
# 1     43743.0
# 2     28898.0
# 3     37133.0
# 4     19665.0
# ..        ...
# 165       NaN
# 166       NaN
# 167       NaN
# 168       NaN
# 169       NaN
#
# [170 rows x 9 columns]

# %%
pay.corr()
# Out:
#                  년도  상용_월평균_임금     임금상승률
# 년도         1.000000   0.489158  0.211368
# 상용_월평균_임금  0.489158   1.000000  0.407682
# 임금상승률      0.211368   0.407682  1.000000

# %%
companies.corr()
# Out:
#           년도        활동        신생        소멸
# 년도  1.000000  0.069110  0.086163  0.024170
# 활동  0.069110  1.000000  0.995701  0.992833
# 신생  0.086163  0.995701  1.000000  0.988414
# 소멸  0.024170  0.992833  0.988414  1.000000

# %%
pd.concat([pay, companies], axis=1).corr()
# Out:
#                  년도  상용_월평균_임금     임금상승률        년도        활동        신생  \
# 년도         1.000000   0.489158  0.211368  1.000000  0.069110  0.086163
# 상용_월평균_임금  0.489158   1.000000  0.407682  0.338964  0.359854  0.347412
# 임금상승률      0.211368   0.407682  1.000000  0.020367  0.116129  0.107762
# 년도         1.000000   0.338964  0.020367  1.000000  0.069110  0.086163
# 활동         0.069110   0.359854  0.116129  0.069110  1.000000  0.995701
# 신생         0.086163   0.347412  0.107762  0.086163  0.995701  1.000000
# 소멸         0.024170   0.345815  0.095966  0.024170  0.992833  0.988414
#
#                  소멸
# 년도         0.024170
# 상용_월평균_임금  0.345815
# 임금상승률      0.095966
# 년도         0.024170
# 활동         0.992833
# 신생         0.988414
# 소멸         1.000000

# %%
sns.heatmap(
    pd.concat([pay, companies], axis=1)[['상용_월평균_임금', '임금상승률', '활동', '신생', '소멸']].corr(),
    annot=True,
    linewidths= 0.5,
)
# Out:
# <AxesSubplot: >

# %% [markdown]
# - 활동, 신생, 소멸은 셋 중 하나만 써야함

# %%
sns.heatmap(
    industries.iloc[:, :52].corr(),
    # annot=True,
    cmap='YlGnBu',
    vmin=0, 
    vmax=1,
    linewidths= 0.5,
    
)
plt.xlabel("")
plt.ylabel("")
plt.title('기업 컬럼 간의 업종별 상관계수', fontsize=22)
# Out:
# Text(0.5, 1.0, '기업 컬럼 간의 업종별 상관계수')

# %%
df = pd.read_csv("../../Data/03.통합.csv")
df_s = df.iloc[:, 3:]


sns.heatmap(
    df_s.corr(),
    annot=True,
    cmap='YlGnBu',
    vmin=0.3, 
    vmax=1,
    linewidths= 0.5,
    
)
plt.xlabel("")
plt.ylabel("")
plt.title('선정된 피쳐 컬럼 간 상관계수', fontsize=22)
# Out:
# Text(0.5, 1.0, '선정된 피쳐 컬럼 간 상관계수')

# %%
industries.columns[:52]
# Out:
# Index(['협회 및 단체, 수리 및 기타 개인서비스업_활동', '협회 및 단체, 수리 및 기타 개인서비스업_신생',
#        '협회 및 단체, 수리 및 기타 개인서비스업_소멸', '예술, 스포츠 및 여가관련 서비스업_활동',
#        '예술, 스포츠 및 여가관련 서비스업_신생', '예술, 스포츠 및 여가관련 서비스업_소멸',
#        '보건업 및 사회복지 서비스업_활동', '보건업 및 사회복지 서비스업_신생', '보건업 및 사회복지 서비스업_소멸',
#        '교육서비스업_활동', '교육서비스업_신생', '교육서비스업_소멸', '사업 시설관리, 사업지원 및 임대 서비스업_활동',
#        '사업 시설관리, 사업지원 및 임대 서비스업_신생', '사업 시설관리, 사업지원 및 임대 서비스업_소멸',
#        '전문, 과학 및 기술서비스업_활동', '전문, 과학 및 기술서비스업_신생', '전문, 과학 및 기술서비스업_소멸',
#        '부동산업_활동', '부동산업_신생', '부동산업_소멸', '금융 및 보험업_활동', '금융 및 보험업_신생',
#        '금융 및 보험업_소멸', '정보통신업_활동', '정보통신업_신생', '정보통신업_소멸', '숙박 및 음식점업_활동',
#        '숙박 및 음식점업_신생', '숙박 및 음식점업_소멸', '운수 및 창고업_활동', '운수 및 창고업_신생',
#        '운수 및 창고업_소멸', '도매 및 소매업_활동', '도매 및 소매업_신생', '도매 및 소매업_소멸', '건설업_활동',
#        '건설업_신생', '건설업_소멸', '수도, 하수 및 폐기물처리, 원료재생업_활동',
#        '수도, 하수 및 폐기물처리, 원료재생업_신생', '수도, 하수 및 폐기물처리, 원료재생업_소멸',
#        '전기, 가스, 증기 및 공기조절 공급업_활동', '전기, 가스, 증기 및 공기조절 공급업_신생',
#        '전기, 가스, 증기 및 공기조절 공급업_소멸', '제조업_활동', '제조업_신생', '제조업_소멸', '광업_활동',
#        '광업_신생', '광업_소멸', '시도'],
#       dtype='object')

# %%
aa = pd.concat([pay, companies], axis=1)[['상용_월평균_임금', '임금상승률', '활동', '신생', '소멸']]
bb = pd.concat([aa, industries.iloc[:, :52]], axis=1)
plt.figure(figsize = (15,15))

sns.heatmap(
    bb.corr(),
    annot_kws={"size": 3},
    linewidths= 0.5,
)
# Out:
# <AxesSubplot: >

# %%
companies['시도']
# industries['지역별']
# Out:
# 0        서울특별시
# 1        부산광역시
# 2        대구광역시
# 3        인천광역시
# 4        광주광역시
#         ...
# 131       전라북도
# 132       전라남도
# 133       경상북도
# 134       경상남도
# 135    제주특별자치도
# Name: 시도, Length: 136, dtype: object

# %%
pd.unique(pay['시도'])
# Out:
# array(['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
#        '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도',
#        '경상남도', '제주특별자치도'], dtype=object)

# %%
sido = []
for i in companies['시도']:
    if i == '서울':
        sido.append('서울특별시')
    elif i == '부산':
        sido.append('부산광역시')
    elif i == '대구':
        sido.append('대구광역시')
    elif i == '인천':
        sido.append('인천광역시')
    elif i == '광주':
        sido.append('광주광역시')
    elif i == '대전':
        sido.append('대전광역시')
    elif i == '울산':
        sido.append('울산광역시')
    elif i == '세종':
        sido.append('세종특별자치시')
    elif i == '경기':
        sido.append('경기도')
    elif i == '강원':
        sido.append('강원도')
    elif i == '충북':
        sido.append('충청북도')
    elif i == '충남':
        sido.append('충청남도')
    elif i == '전북':
        sido.append('전라북도')
    elif i == '전남':
        sido.append('전라남도')
    elif i == '경북':
        sido.append('경상북도')
    elif i == '경남':
        sido.append('경상남도')
    elif i == '제주':
        sido.append('제주특별자치도')
sido
# Out:
# []

# %%
companies['시도'] = sido
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 companies['시도'] = sido
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
#    4177         and not is_extension_array_dtype(value)
#    4178     ):
#    4179         # broadcast across multiple columns if necessary
#    4180         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/frame.py:4912, in DataFrame._sanitize_column(self, value)
#    4909     return _reindex_for_setitem(Series(value), self.index)
#    4911 if is_list_like(value):
# -> 4912     com.require_length_match(value, self.index)
#    4913 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (0) does not match length of index (136)

# %%
sido = []
for i in industries['지역별']:
    if i == '서울':
        sido.append('서울특별시')
    elif i == '부산':
        sido.append('부산광역시')
    elif i == '대구':
        sido.append('대구광역시')
    elif i == '인천':
        sido.append('인천광역시')
    elif i == '광주':
        sido.append('광주광역시')
    elif i == '대전':
        sido.append('대전광역시')
    elif i == '울산':
        sido.append('울산광역시')
    elif i == '세종':
        sido.append('세종특별자치시')
    elif i == '경기':
        sido.append('경기도')
    elif i == '강원':
        sido.append('강원도')
    elif i == '충북':
        sido.append('충청북도')
    elif i == '충남':
        sido.append('충청남도')
    elif i == '전북':
        sido.append('전라북도')
    elif i == '전남':
        sido.append('전라남도')
    elif i == '경북':
        sido.append('경상북도')
    elif i == '경남':
        sido.append('경상남도')
    elif i == '제주':
        sido.append('제주특별자치도')
    else:
        sido.append('전국')
        
len(sido)
industries.drop('지역별', axis=1, inplace=True)
industries['시도'] = sido
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '지역별'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 sido = []
# ----> 2 for i in industries['지역별']:
#       3     if i == '서울':
#       4         sido.append('서울특별시')
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: '지역별'

# %%
pd.unique(industries['지역별'])
# Out:
# array(['전국', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원',
#        '충북', '충남', '전북', '전남', '경북', '경남', '제주'], dtype=object)

# %%
# industries.to_csv("../../Data/companies/정제_업종_전부(2013~2020).csv", encoding='utf-8', index=False)

# %%
# companies.to_csv("../../Data/companies/정제_시도별_전체_기업수(2013~2020).csv", encoding='utf-8', index=False)

# %%
companies
# Out:
#           시도    년도       활동      신생      소멸
# 0      서울특별시  2013  1258829  168425  150812
# 1      부산광역시  2013   370922   49110   43743
# 2      대구광역시  2013   255803   33186   28898
# 3      인천광역시  2013   278236   41563   37133
# 4      광주광역시  2013   142802   22274   19665
# ..       ...   ...      ...     ...     ...
# 131     전라북도  2020   224779   35752   23203
# 132     전라남도  2020   219445   34249   22803
# 133     경상북도  2020   322277   44946   33437
# 134     경상남도  2020   403797   58729   45268
# 135  제주특별자치도  2020   102151   16875   12269
#
# [136 rows x 5 columns]

# %%
industries
# Out:
#      협회 및 단체, 수리 및 기타 개인서비스업_활동  협회 및 단체, 수리 및 기타 개인서비스업_신생  \
# 0                         47929                        5870
# 1                         17554                        1892
# 2                         11126                        1400
# 3                         12099                        1931
# 4                          7586                        1086
# ..                          ...                         ...
# 131                       11770                        1675
# 132                       11167                        1733
# 133                       17024                        2354
# 134                       21223                        3176
# 135                        4745                         703
#
#      협회 및 단체, 수리 및 기타 개인서비스업_소멸  예술, 스포츠 및 여가관련 서비스업_활동  \
# 0                          6229                   24426
# 1                          2093                    6967
# 2                          1301                    5129
# 3                          1769                    6050
# 4                          1086                    3430
# ..                          ...                     ...
# 131                        1260                    3933
# 132                        1342                    3663
# 133                        1827                    5765
# 134                        2337                    6929
# 135                         595                    2107
#
#      예술, 스포츠 및 여가관련 서비스업_신생  예술, 스포츠 및 여가관련 서비스업_소멸  보건업 및 사회복지 서비스업_활동  \
# 0                      4488                    4716               18641
# 1                      1146                    1292                5023
# 2                       862                     929                3773
# 3                      1218                    1283                3263
# 4                       782                     841                2186
# ..                      ...                     ...                 ...
# 131                     713                     674                2696
# 132                     752                     670                2198
# 133                     930                     983                3021
# 134                    1155                    1185                4074
# 135                     400                     276                1000
#
#      보건업 및 사회복지 서비스업_신생  보건업 및 사회복지 서비스업_소멸  교육서비스업_활동  ...  \
# 0                  1666                1389      28184  ...
# 1                   394                 280       8354  ...
# 2                   245                 192       6666  ...
# 3                   298                 223       5995  ...
# 4                   221                 166       4819  ...
# ..                  ...                 ...        ...  ...
# 131                 132                  94       6035  ...
# 132                 101                  83       4567  ...
# 133                 119                 120       7648  ...
# 134                 197                 159      11810  ...
# 135                  43                  22       2682  ...
#
#      전기, 가스, 증기 및 공기조절 공급업_활동  전기, 가스, 증기 및 공기조절 공급업_신생  \
# 0                         163                        45
# 1                          39                        14
# 2                          86                        11
# 3                          54                        10
# 4                         151                        62
# ..                        ...                       ...
# 131                     18102                      5800
# 132                     10767                      3502
# 133                      7750                      2617
# 134                      4140                      1286
# 135                       995                       290
#
#      전기, 가스, 증기 및 공기조절 공급업_소멸  제조업_활동  제조업_신생  제조업_소멸  광업_활동  광업_신생  광업_소멸  \
# 0                           9   74080    7362    6401     53      6      4
# 1                           1   35083    3208    2694     13      1      1
# 2                           1   29884    2640    1936     12      4      4
# 3                           2   30778    3168    2594     21      1      1
# 4                           5    9376    1051     808     15      2      0
# ..                        ...     ...     ...     ...    ...    ...    ...
# 131                       496   14377    1573    1216     90      9      8
# 132                       378   14892    1720    1310    528    128    117
# 133                       260   34547    3277    2702    189     13     20
# 134                       130   47130    4090    3648     86     11      9
# 135                        22    3302     383     263     18      0      2
#
#           시도
# 0      서울특별시
# 1      부산광역시
# 2      대구광역시
# 3      인천광역시
# 4      광주광역시
# ..       ...
# 131     전라북도
# 132     전라남도
# 133     경상북도
# 134     경상남도
# 135  제주특별자치도
#
# [136 rows x 52 columns]

# %%
len(industries)
# Out:
# 136

# %%
17*8
# Out:
# 136

# %%
years = []

for i in range(2013, 2021):
    for _ in range(17):
        years.append(i)
years
# Out:
# [2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020]

# %%
industries['년도'] = years
industries
# Out:
#      협회 및 단체, 수리 및 기타 개인서비스업_활동  협회 및 단체, 수리 및 기타 개인서비스업_신생  \
# 0                         47929                        5870
# 1                         17554                        1892
# 2                         11126                        1400
# 3                         12099                        1931
# 4                          7586                        1086
# ..                          ...                         ...
# 131                       11770                        1675
# 132                       11167                        1733
# 133                       17024                        2354
# 134                       21223                        3176
# 135                        4745                         703
#
#      협회 및 단체, 수리 및 기타 개인서비스업_소멸  예술, 스포츠 및 여가관련 서비스업_활동  \
# 0                          6229                   24426
# 1                          2093                    6967
# 2                          1301                    5129
# 3                          1769                    6050
# 4                          1086                    3430
# ..                          ...                     ...
# 131                        1260                    3933
# 132                        1342                    3663
# 133                        1827                    5765
# 134                        2337                    6929
# 135                         595                    2107
#
#      예술, 스포츠 및 여가관련 서비스업_신생  예술, 스포츠 및 여가관련 서비스업_소멸  보건업 및 사회복지 서비스업_활동  \
# 0                      4488                    4716               18641
# 1                      1146                    1292                5023
# 2                       862                     929                3773
# 3                      1218                    1283                3263
# 4                       782                     841                2186
# ..                      ...                     ...                 ...
# 131                     713                     674                2696
# 132                     752                     670                2198
# 133                     930                     983                3021
# 134                    1155                    1185                4074
# 135                     400                     276                1000
#
#      보건업 및 사회복지 서비스업_신생  보건업 및 사회복지 서비스업_소멸  교육서비스업_활동  ...  \
# 0                  1666                1389      28184  ...
# 1                   394                 280       8354  ...
# 2                   245                 192       6666  ...
# 3                   298                 223       5995  ...
# 4                   221                 166       4819  ...
# ..                  ...                 ...        ...  ...
# 131                 132                  94       6035  ...
# 132                 101                  83       4567  ...
# 133                 119                 120       7648  ...
# 134                 197                 159      11810  ...
# 135                  43                  22       2682  ...
#
#      전기, 가스, 증기 및 공기조절 공급업_신생  전기, 가스, 증기 및 공기조절 공급업_소멸  제조업_활동  제조업_신생  \
# 0                          45                         9   74080    7362
# 1                          14                         1   35083    3208
# 2                          11                         1   29884    2640
# 3                          10                         2   30778    3168
# 4                          62                         5    9376    1051
# ..                        ...                       ...     ...     ...
# 131                      5800                       496   14377    1573
# 132                      3502                       378   14892    1720
# 133                      2617                       260   34547    3277
# 134                      1286                       130   47130    4090
# 135                       290                        22    3302     383
#
#      제조업_소멸  광업_활동  광업_신생  광업_소멸       시도    년도
# 0      6401     53      6      4    서울특별시  2013
# 1      2694     13      1      1    부산광역시  2013
# 2      1936     12      4      4    대구광역시  2013
# 3      2594     21      1      1    인천광역시  2013
# 4       808     15      2      0    광주광역시  2013
# ..      ...    ...    ...    ...      ...   ...
# 131    1216     90      9      8     전라북도  2020
# 132    1310    528    128    117     전라남도  2020
# 133    2702    189     13     20     경상북도  2020
# 134    3648     86     11      9     경상남도  2020
# 135     263     18      0      2  제주특별자치도  2020
#
# [136 rows x 53 columns]

# %%
industries.to_csv("../../Data/companies/정제_업종_전부(2013~2020).csv", encoding='utf-8', index=False)
