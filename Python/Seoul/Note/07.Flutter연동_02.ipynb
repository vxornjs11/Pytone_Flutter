# %% [markdown]
# # 서울시 군구별 입력값을 받아 시각화하기
# ### - 지역명 입력 -> 2013-2021 포인트&라인 차트로 표현

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../Data/seoul_pred.csv")
df
# Out:
#       군구    년도   전출인구  출생아수  산부인과의원수  초등학교수  cluster_id  pred_cluster
# 0    종로구  2013  30007   873        9     14        1.00      0.024546
# 1    종로구  2014  27484   905        9     14        1.00     -0.011985
# 2    종로구  2015  27470   906        9     14        1.00     -0.012197
# 3    종로구  2016  26386   846        9     13        1.00     -0.026231
# 4    종로구  2017  25814   689        9     13        1.00     -0.032745
# ..   ...   ...    ...   ...      ...    ...         ...           ...
# 220  강동구  2017  90819  2968       18     27        0.33      0.858726
# 221  강동구  2018  68933  2659       17     27        0.33      0.548615
# 222  강동구  2019  67292  2437       17     27        0.33      0.527468
# 223  강동구  2020  78271  2535       17     28        0.33      0.683014
# 224  강동구  2021  74444  2810       19     29        0.33      0.623364
#
# [225 rows x 8 columns]

# %%
gungu = '종로구'
# df[df['군구'] == gungu][['년도','pred_cluster']].to_dict()
# df[df['군구'] == gungu][['년도','pred_cluster']].to_dict('list')
df[df['군구'] == gungu][['년도']]
# Out:
#      년도
# 0  2013
# 1  2014
# 2  2015
# 3  2016
# 4  2017
# 5  2018
# 6  2019
# 7  2020
# 8  2021

# %%
df['pred_cluster'] = round(df['pred_cluster'],2)

# %%
gungu = '종로구'
df[df['군구'] == gungu]['pred_cluster'].tolist()
# Out:
# [0.02, -0.01, -0.01, -0.03, -0.03, -0.05, -0.06, -0.04, -0.05]

# %%
# from flask import Flask, jsonify, render_template, request # 플라스크에 대한 얘기임
# import joblib

# app = Flask(__name__)

# @app.route("/gungu")
# def seoul_gungu():
#     gungu = request.args.get("gungu")
#     df = pd.read_csv("./PythonSpace/seoul_3.csv")
#     df
    
#     # gungu = '종로구'
#     res = df[df['군구'] == gungu]['pred_cluster'].tolist()
#     print(gungu)

#     return jsonify({'result' : res})


# # 내가실행하는게 아니라 플러터에서 실행하는것   # 파이썬에서는 런메소드가 제일 뒤에 있다.
# if __name__ == "__main__": # 자바의 메인 메소드
#     app.run(host="127.0.0.1", port=5000, debug=True)


# # 크롬으로 잘돌아가는지 확인하고, 소스보기로 이상한 소스 없는지도 확인하기 <

# %% [markdown]
# ----

# %%
pd.DataFrame(df[['년도','군구','pred_cluster']])
# Out:
#        년도   군구  pred_cluster
# 0    2013  종로구          0.02
# 1    2014  종로구         -0.01
# 2    2015  종로구         -0.01
# 3    2016  종로구         -0.03
# 4    2017  종로구         -0.03
# ..    ...  ...           ...
# 220  2017  강동구          0.86
# 221  2018  강동구          0.55
# 222  2019  강동구          0.53
# 223  2020  강동구          0.68
# 224  2021  강동구          0.62
#
# [225 rows x 3 columns]

# %%
gungu_list = df['군구'].unique()
gungu_list
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
gungu_dict = {}
gungu_dict['년도'] = df['년도'].unique().tolist()
gungu_dict['군구'] = df['군구'].unique().tolist()
for gungu in gungu_list:
    gungu_dict[gungu] = df['pred_cluster'][df['군구'] == gungu].tolist()
gungu_dict
# Out:
# {'년도': [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],
#  '군구': ['종로구',
#   '중구',
#   '용산구',
#   '성동구',
#   '광진구',
#   '동대문구',
#   '중랑구',
#   '성북구',
#   '강북구',
#   '도봉구',
#   '노원구',
#   '은평구',
#   '서대문구',
#   '마포구',
#   '양천구',
#   '강서구',
#   '구로구',
#   '금천구',
#   '영등포구',
#   '동작구',
#   '관악구',
#   '서초구',
#   '강남구',
#   '송파구',
#   '강동구'],
#  '종로구': [0.02, -0.01, -0.01, -0.03, -0.03, -0.05, -0.06, -0.04, -0.05],
#  '중구': [-0.08, -0.08, -0.08, -0.09, -0.11, -0.1, -0.13, -0.09, -0.1],
#  '용산구': [0.15, 0.17, 0.18, 0.14, 0.11, 0.13, 0.1, 0.15, 0.16],
#  '성동구': [0.25, 0.31, 0.27, 0.24, 0.23, 0.28, 0.26, 0.34, 0.24],
#  '광진구': [0.43, 0.48, 0.48, 0.43, 0.38, 0.41, 0.39, 0.45, 0.39],
#  '동대문구': [0.37, 0.42, 0.44, 0.37, 0.33, 0.4, 0.34, 0.41, 0.31],
#  '중랑구': [0.5, 0.54, 0.58, 0.49, 0.43, 0.42, 0.37, 0.47, 0.41],
#  '성북구': [0.57, 0.65, 0.64, 0.56, 0.54, 0.5, 0.44, 0.55, 0.46],
#  '강북구': [0.33, 0.33, 0.33, 0.28, 0.23, 0.25, 0.2, 0.26, 0.21],
#  '도봉구': [0.32, 0.31, 0.32, 0.27, 0.23, 0.21, 0.17, 0.27, 0.2],
#  '노원구': [0.72, 0.73, 0.73, 0.7, 0.66, 0.59, 0.52, 0.67, 0.53],
#  '은평구': [0.65, 0.7, 0.77, 0.74, 0.61, 0.58, 0.6, 0.66, 0.53],
#  '서대문구': [0.29, 0.29, 0.37, 0.35, 0.3, 0.28, 0.25, 0.35, 0.26],
#  '마포구': [0.49, 0.52, 0.59, 0.6, 0.47, 0.44, 0.42, 0.55, 0.46],
#  '양천구': [0.53, 0.56, 0.56, 0.62, 0.46, 0.46, 0.38, 0.54, 0.43],
#  '강서구': [0.76, 0.91, 0.88, 0.86, 0.77, 0.83, 0.76, 0.97, 0.86],
#  '구로구': [0.44, 0.48, 0.47, 0.44, 0.4, 0.4, 0.33, 0.49, 0.35],
#  '금천구': [0.13, 0.11, 0.12, 0.11, 0.08, 0.09, 0.07, 0.12, 0.09],
#  '영등포구': [0.49, 0.5, 0.49, 0.59, 0.51, 0.45, 0.4, 0.55, 0.44],
#  '동작구': [0.53, 0.55, 0.65, 0.54, 0.53, 0.52, 0.46, 0.57, 0.56],
#  '관악구': [0.94, 0.96, 0.99, 0.93, 0.92, 0.95, 0.94, 1.05, 0.95],
#  '서초구': [0.65, 0.61, 0.74, 0.61, 0.65, 0.75, 0.53, 0.68, 0.73],
#  '강남구': [0.96, 1.02, 1.16, 1.09, 1.01, 1.07, 0.88, 1.0, 0.95],
#  '송파구': [1.07, 1.05, 1.11, 1.13, 1.06, 0.98, 1.19, 1.2, 1.17],
#  '강동구': [0.63, 0.63, 0.9, 0.77, 0.86, 0.55, 0.53, 0.68, 0.62]}
